# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
# Your code here - remember to use markdown cells for comments as well!

# %% [markdown]
# Daniel Katete Ogando

# %% [markdown]
# Part-Time

# %% [markdown]
# 24th November 2024

# %% [markdown]
# Noah Kandie(TM)/Bonface Manyara
